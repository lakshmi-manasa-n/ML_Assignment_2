# %% [markdown]
# # Machine Learning Assignment 2
# ## Email Spam Classification using UCI Spambase
#
# This notebook trains Logistic Regression, Decision Tree, kNN, Gaussian Naive Bayes and Random Forest and evaluates them using Accuracy, AUC, Precision, Recall, F1 and MCC.

# %%
# Run the complete training script from this notebook
from pathlib import Path
import os, runpy

cwd = Path.cwd()
if cwd.name == 'model':
    script_path = cwd / 'train_models.py'
else:
    script_path = cwd / 'model' / 'train_models.py'

print('Running:', script_path)
runpy.run_path(str(script_path), run_name='__main__')

# %% [markdown]
# ## After successful execution
# Check the generated `model_comparison_results.csv` and use those exact values in your README and final submission PDF.
